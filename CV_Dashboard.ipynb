# %% [markdown]
# # Cardiovascular Dashboard

# %% [markdown]
# #### Environment Setup

# %%
import pandas as pd
import numpy as np
import panel as pn
pn.extension('tabulator')

import hvplot.pandas
import holoviews as hv
hv.extension('bokeh')

from holoviews.selection import link_selections
from holoviews import opts
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>

# %% [markdown]
# #### Data

# %%
df = pd.read_csv('https://chronicdata.cdc.gov/api/views/kztq-p2jf/rows.csv?accessType=DOWNLOAD&api_foundry=true')

pd.set_option('display.max_rows', 20)  
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', 100)

df = df.dropna(subset = ['Data_Value'])
df
# Out:
#                                            row_id  Year LocationAbbr  \
# 0                  NVSS~2003~32~NV005~AGE08~Crude  2003           NV
# 1                  NVSS~2007~59~NV001~AGE08~Crude  2007           US
# 2                  NVSS~2012~59~NV001~RAC07~Crude  2012           US
# 3                  NVSS~2011~59~NV001~GEN02~Crude  2011           US
# 4                  NVSS~2010~59~NV001~AGE05~Crude  2010           US
# ...                                           ...   ...          ...
# 158075             NVSS~2012~15~NV008~GEN01~Crude  2012           HI
# 158076             NVSS~2015~06~NV008~AGE04~Crude  2015           CA
# 158077  NVSS~2013~06~NV008~RAC01~Age-Standardized  2013           CA
# 158078             NVSS~2012~19~NV008~GEN01~Crude  2012           IA
# 158079  NVSS~2013~04~NV008~OVR01~Age-Standardized  2013           AZ
#
#          LocationDesc DataSource PriorityArea1 PriorityArea2 PriorityArea3  \
# 0              Nevada       NVSS          None          None          None
# 1       United States       NVSS          None          None          None
# 2       United States       NVSS          None          None          None
# 3       United States       NVSS          None          None          None
# 4       United States       NVSS          None          None          None
# ...               ...        ...           ...           ...           ...
# 158075         Hawaii       NVSS          None          None          None
# 158076     California       NVSS          None          None          None
# 158077     California       NVSS          None          None          None
# 158078           Iowa       NVSS          None          None          None
# 158079        Arizona       NVSS          None          None          None
#
#        PriorityArea4                 Category                         Topic  \
# 0               None  Cardiovascular Diseases                 Heart Failure
# 1               None  Cardiovascular Diseases  Major Cardiovascular Disease
# 2               None  Cardiovascular Diseases  Major Cardiovascular Disease
# 3               None  Cardiovascular Diseases  Major Cardiovascular Disease
# 4               None  Cardiovascular Diseases  Major Cardiovascular Disease
# ...              ...                      ...                           ...
# 158075          None  Cardiovascular Diseases                        Stroke
# 158076          None  Cardiovascular Diseases                        Stroke
# 158077          None  Cardiovascular Diseases                        Stroke
# 158078          None  Cardiovascular Diseases                        Stroke
# 158079          None  Cardiovascular Diseases                        Stroke
#
#                                                                          Indicator  \
# 0                      Rate of heart failure mortality among US adults (18+); NVSS
# 1       Rate of major cardiovascular disease mortality among US adults (18+); NVSS
# 2       Rate of major cardiovascular disease mortality among US adults (18+); NVSS
# 3       Rate of major cardiovascular disease mortality among US adults (18+); NVSS
# 4       Rate of major cardiovascular disease mortality among US adults (18+); NVSS
# ...                                                                            ...
# 158075            Rate of hemorrhagic stroke mortality among US adults (18+); NVSS
# 158076            Rate of hemorrhagic stroke mortality among US adults (18+); NVSS
# 158077            Rate of hemorrhagic stroke mortality among US adults (18+); NVSS
# 158078            Rate of hemorrhagic stroke mortality among US adults (18+); NVSS
# 158079            Rate of hemorrhagic stroke mortality among US adults (18+); NVSS
#
#          Data_Value_Type   Data_Value_Unit  Data_Value  Data_Value_Alt  \
# 0                  Crude  Rate per 100,000       333.7           333.7
# 1                  Crude  Rate per 100,000      2933.6          2933.6
# 2                  Crude  Rate per 100,000       138.2           138.2
# 3                  Crude  Rate per 100,000       322.2           322.2
# 4                  Crude  Rate per 100,000       157.8           157.8
# ...                  ...               ...         ...             ...
# 158075             Crude  Rate per 100,000        17.0            17.0
# 158076             Crude  Rate per 100,000         2.0             2.0
# 158077  Age-Standardized  Rate per 100,000        10.0            10.0
# 158078             Crude  Rate per 100,000        11.2            11.2
# 158079  Age-Standardized  Rate per 100,000         8.8             8.8
#
#        Data_Value_Footnote_Symbol Data_Value_Footnote  LowConfidenceLimit  \
# 0                             NaN                 NaN               333.6
# 1                             NaN                 NaN              2933.6
# 2                             NaN                 NaN               138.2
# 3                             NaN                 NaN               322.2
# 4                             NaN                 NaN               157.8
# ...                           ...                 ...                 ...
# 158075                        NaN                 NaN                16.8
# 158076                        NaN                 NaN                 1.9
# 158077                        NaN                 NaN                10.0
# 158078                        NaN                 NaN                11.0
# 158079                        NaN                 NaN                 8.7
#
#         HighConfidenceLimit Break_Out_Category           Break_Out CategoryId  \
# 0                     333.8                Age                 75+         C1
# 1                    2933.6                Age                 75+         C1
# 2                     138.2               Race               Other         C1
# 3                     322.2             Gender              Female         C1
# 4                     157.8                Age               45-64         C1
# ...                     ...                ...                 ...        ...
# 158075                 20.8             Gender                Male         C1
# 158076                  2.1                Age               25-44         C1
# 158077                 10.0               Race  Non-Hispanic White         C1
# 158078                 11.4             Gender                Male         C1
# 158079                  8.9            Overall             Overall         C1
#
#        TopicId IndicatorID Data_Value_TypeID BreakOutCategoryId BreakOutId  \
# 0           T5       NV005             Crude              BOC03      AGE08
# 1           T1       NV001             Crude              BOC03      AGE08
# 2           T1       NV001             Crude              BOC04      RAC07
# 3           T1       NV001             Crude              BOC02      GEN02
# 4           T1       NV001             Crude              BOC03      AGE05
# ...        ...         ...               ...                ...        ...
# 158075      T6       NV008             Crude              BOC02      GEN01
# 158076      T6       NV008             Crude              BOC03      AGE04
# 158077      T6       NV008           AgeStdz              BOC04      RAC01
# 158078      T6       NV008             Crude              BOC02      GEN01
# 158079      T6       NV008           AgeStdz              BOC01      OVR01
#
#         LocationID                                     GeoLocation
# 0               32  POINT (-117.07184056399967 39.493240390000494)
# 1               59                                             NaN
# 2               59                                             NaN
# 3               59                                             NaN
# 4               59                                             NaN
# ...            ...                                             ...
# 158075          15  POINT (-157.85774940299973 21.304850435000446)
# 158076           6   POINT (-120.99999953799971 37.63864012300047)
# 158077           6   POINT (-120.99999953799971 37.63864012300047)
# 158078          19    POINT (-93.81649055599968 42.46940091300047)
# 158079           4  POINT (-111.76381127699972 34.865970280000454)
#
# [129093 rows x 30 columns]

# %%
df['Break_Out_Category'].unique()
# Out:
# array(['Age', 'Race', 'Gender', 'Overall'], dtype=object)

# %%
race = df[(df['Break_Out_Category'] == 'Race')]
race['Break_Out'].unique()
# Out:
# array(['Other', 'Non-Hispanic Black', 'Hispanic', 'Non-Hispanic White'],
#       dtype=object)

# %%
disease = df.replace(['Diseases of the Heart (Heart Disease)','Acute Myocardial Infarction (Heart Attack)'], ['Diseases of the Heart','Acute Myocardial Infarction'], inplace=True)
race = df.replace(['Non-Hispanic Black','Non-Hispanic White'], ['Black','White'], inplace=True)

df['Topic'].unique()
# Out:
# array(['Heart Failure', 'Major Cardiovascular Disease', 'Stroke',
#        'Diseases of the Heart', 'Coronary Heart Disease',
#        'Acute Myocardial Infarction'], dtype=object)

# %%
df['Break_Out'].unique()
# Out:
# array(['75+', 'Other', 'Female', '45-64', '25-44', '65+', '35+', '18-24',
#        'Male', 'Black', 'Hispanic', 'Overall', 'White'], dtype=object)

# %%
idf = df.interactive()

# %% [markdown]
# #### Widgets

# %%
menu_items =list(df['LocationDesc'].unique())
menu_items.remove('United States')
menu_items.remove('Washington, DC')
menu_items.sort()

state_select = pn.widgets.Select(name='State', options=menu_items)
state_select
# Out:
# Select(name='State', options=['Alabama', 'Alaska', ...], value='Alabama')

# %%
Year=list(df['Year'].unique())
Year.sort()
year_select = pn.widgets.Select(name='Year', options=Year)
year_select
# Out:
# Select(name='Year', options=[2000, 2001, 2002, ...], value=2000)

# %%
disease_states = df['Topic'].unique()
disease_items = list(disease_states)
disease_select = pn.widgets.Select(name='Disease', options=disease_items)
disease_select
# Out:
# Select(name='Disease', options=['Heart Failure', ...], value='Heart Failure')

# %% [markdown]
# #### Disease State Timeline

# %%
disease_pipeline = (
    idf[
        (idf.Year <= 2018) &
        (idf.Topic.isin(disease_states)) &
        (idf.LocationDesc == 'United States') &
        (idf.Break_Out_Category == 'Overall') &
        (idf.Data_Value_TypeID == 'AgeStdz')
    ]
    .groupby(['Topic','Year'])['Data_Value'].sum()
    .to_frame()
    .reset_index()
    .sort_values(by='Year')
    .reset_index(drop=True)
)

# %%
disease_pipeline
# Out:
# <div id='1009'>
#   <div class="bk-root" id="5c87f087-51fd-4139-86e4-1cc8054f208e" data-root-id="1009"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"72f0ef4c-32ca-43fc-8955-ae99870f8581":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"NotificationAreaBase1","overrides":[],"properties":[{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"}]},{"extends":null,"module":null,"name":"NotificationArea1","overrides":[],"properties":[{"default":[],"kind":null,"name":"notifications"},{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"},{"default":[{"background":"#ffc107","icon":{"className":"fas fa-exclamation-triangle","color":"white","tagName":"i"},"type":"warning"},{"background":"#007bff","icon":{"className":"fas fa-info-circle","color":"white","tagName":"i"},"type":"info"}],"kind":null,"name":"types"}]},{"extends":null,"module":null,"name":"Notification","overrides":[],"properties":[{"default":null,"kind":null,"name":"background"},{"default":3000,"kind":null,"name":"duration"},{"default":null,"kind":null,"name":"icon"},{"default":"","kind":null,"name":"message"},{"default":null,"kind":null,"name":"notification_type"},{"default":false,"kind":null,"name":"_destroyed"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"margin":[0,0,0,0],"name":"Column02705"},"id":"1015","type":"Column"},{"attributes":{"margin":[0,0,0,0],"name":"Column02647"},"id":"1012","type":"Column"},{"attributes":{"children":[{"id":"1010"}],"margin":[0,0,0,0],"name":"Row02709"},"id":"1009","type":"Row"},{"attributes":{"margin":[5,5,5,5],"name":"DataFrame02702","text":"&lt;table class=&quot;dataframe panel-df&quot;&gt;\n  &lt;thead&gt;\n    &lt;tr style=&quot;text-align: right;&quot;&gt;\n      &lt;th&gt;&lt;/th&gt;\n      &lt;th&gt;Topic&lt;/th&gt;\n      &lt;th&gt;Year&lt;/th&gt;\n      &lt;th&gt;Data_Value&lt;/th&gt;\n    &lt;/tr&gt;\n  &lt;/thead&gt;\n  &lt;tbody&gt;\n    &lt;tr&gt;\n      &lt;th&gt;0&lt;/th&gt;\n      &lt;td&gt;Acute Myocardial Infarction&lt;/td&gt;\n      &lt;td&gt;2000&lt;/td&gt;\n      &lt;td&gt;93.4&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;1&lt;/th&gt;\n      &lt;td&gt;Heart Failure&lt;/td&gt;\n      &lt;td&gt;2000&lt;/td&gt;\n      &lt;td&gt;26.9&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;2&lt;/th&gt;\n      &lt;td&gt;Diseases of the Heart&lt;/td&gt;\n      &lt;td&gt;2000&lt;/td&gt;\n      &lt;td&gt;343.5&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;3&lt;/th&gt;\n      &lt;td&gt;Stroke&lt;/td&gt;\n      &lt;td&gt;2000&lt;/td&gt;\n      &lt;td&gt;147.7&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;4&lt;/th&gt;\n      &lt;td&gt;Coronary Heart Disease&lt;/t ...

# %%
disease_state_timeline = disease_pipeline.hvplot(frame_width=800,
                                                 frame_height=175,
                                                 x='Year',
                                                 y='Data_Value',
                                                 by='Topic',
                                                 ylabel='Incidence Rate Per 100,000',
                                                 line_width=1.5,
                                                 color=['pink','red','crimson','indianred','firebrick','darkred'],
                                                 title="CV Disease in USA (2000-2018)")
disease_state_timeline
# Out:
# <div id='1019'>
#   <div class="bk-root" id="d37079fe-fc26-4542-99f2-d41dec181b58" data-root-id="1019"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"ba04bff7-fe95-4fbd-a30d-fe3d29ee6c92":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"NotificationAreaBase1","overrides":[],"properties":[{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"}]},{"extends":null,"module":null,"name":"NotificationArea1","overrides":[],"properties":[{"default":[],"kind":null,"name":"notifications"},{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"},{"default":[{"background":"#ffc107","icon":{"className":"fas fa-exclamation-triangle","color":"white","tagName":"i"},"type":"warning"},{"background":"#007bff","icon":{"className":"fas fa-info-circle","color":"white","tagName":"i"},"type":"info"}],"kind":null,"name":"types"}]},{"extends":null,"module":null,"name":"Notification","overrides":[],"properties":[{"default":null,"kind":null,"name":"background"},{"default":3000,"kind":null,"name":"duration"},{"default":null,"kind":null,"name":"icon"},{"default":"","kind":null,"name":"message"},{"default":null,"kind":null,"name":"notification_type"},{"default":false,"kind":null,"name":"_destroyed"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"coordinates":null,"data_source":{"id":"1068"},"glyph":{"id":"1071"},"group":null,"hover_glyph":null,"muted_glyph":{"id":"1073"},"nonselection_glyph":{"id":"1072"},"selection_glyph":{"id":"1088"},"view":{"id":"1075"}},"id":"1074","type":"GlyphRenderer"},{"attributes":{},"id":"1214","type":"UnionRenderers"},{"attributes":{"line_color":"red","line_width":1.5,"x":{"field":"Year"},"y":{"field":"Data_Value"}},"id":"1110","type":"Line"},{"attributes":{"line_alpha":0.2,"line_color":"crimson","line_width":1.5,"x":{"field":"Year"},"y":{"field":"Data_Value"}},"id":"1116","type":"Line"},{"attributes":{"line_alpha":0.2,"line_color":"pink","line_width":1.5,"x":{"field":"Year"},"y":{"field":"Data_Value"}},"id":"1073","type":"Line"},{"attributes":{"line_color":"crimson","line_width":1.5,"x":{"field":"Year"},"y":{"field":"Data_Value"}},"id":"1114","type":"Line"},{"attributes":{"client_comm_id":"d3178900872746e8bea25c04c5d1c4d7","comm_id":"1004afaf6f0c4537b85817523b14eee5","plot_id":"1019"},"id":"1299","type":"panel.models.comm_manager.CommManager"},{"attributes":{},"id":"1064","type":"AllLabels"},{"attributes":{"line_color":"indianred","line_width":1.5,"x":{"field":"Year"},"y":{"field":"Data_Value"}},"id":"1138","type":"Line"},{"attributes":{},"id":"1063","type":"BasicTickFormatter"},{"attributes":{"data":{"Data_Value":{"__ndarray__":"zczMzMxMfEBmZmZmZoZ7QGZmZmZmBntAZmZmZmYGekCamZmZmWl4QJqZmZmZ2XdAZmZmZmaOdkBmZmZmZmZ1QM ...

# %%
age = df[(df['Break_Out_Category'] == 'Age')]
age = list(age['Break_Out'].unique())

# %% [markdown]
# #### Disease Rate by State Bar Chart

# %%
disease_states_bar_pipeline = (
    idf[
        (idf.LocationDesc == state_select) &
        (idf.Topic.isin(disease_states)) &
        (idf.Break_Out_Category == 'Overall') &
        (idf.Data_Value_TypeID == 'AgeStdz')
    ]
    .groupby(['LocationDesc','Topic'])['Data_Value'].mean()
    .to_frame()
    .reset_index()
    .sort_values(by='LocationDesc')
    .reset_index(drop=True)
)

# %%
disease_states_bar_pipeline
# Out:
# <div id='1400'>
#   <div class="bk-root" id="9767fa85-c7ac-4986-8ace-5a87b86bbd63" data-root-id="1400"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"5087f479-ce1b-44d5-a797-950c30fefe3a":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"NotificationAreaBase1","overrides":[],"properties":[{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"}]},{"extends":null,"module":null,"name":"NotificationArea1","overrides":[],"properties":[{"default":[],"kind":null,"name":"notifications"},{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"},{"default":[{"background":"#ffc107","icon":{"className":"fas fa-exclamation-triangle","color":"white","tagName":"i"},"type":"warning"},{"background":"#007bff","icon":{"className":"fas fa-info-circle","color":"white","tagName":"i"},"type":"info"}],"kind":null,"name":"types"}]},{"extends":null,"module":null,"name":"Notification","overrides":[],"properties":[{"default":null,"kind":null,"name":"background"},{"default":3000,"kind":null,"name":"duration"},{"default":null,"kind":null,"name":"icon"},{"default":"","kind":null,"name":"message"},{"default":null,"kind":null,"name":"notification_type"},{"default":false,"kind":null,"name":"_destroyed"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"children":[{"id":"1401"}],"margin":[0,0,0,0],"name":"Row04959"},"id":"1400","type":"Row"},{"attributes":{"margin":[5,10,5,10],"options":["Alabama","Alaska","Arizona","Arkansas","California","Colorado","Connecticut","Delaware","Florida","Georgia","Hawaii","Idaho","Illinois","Indiana","Iowa","Kansas","Kentucky","Louisiana","Maine","Maryland","Massachusetts","Michigan","Minnesota","Mississippi","Missouri","Montana","Nebraska","Nevada","New Hampshire","New Jersey","New Mexico","New York","North Carolina","North Dakota","Ohio","Oklahoma","Oregon","Pennsylvania","Rhode Island","South Carolina","South Dakota","Tennessee","Texas","Utah","Vermont","Virginia","Washington","West Virginia","Wisconsin","Wyoming"],"title":"State","value":"Alabama"},"id":"1404","type":"panel.models.widgets.CustomSelect"},{"attributes":{"children":[{"id":"1407"}],"margin":[0,0,0,0],"name":"Row04904"},"id":"1406","type":"Row"},{"attributes":{"children":[{"id":"1404"}],"margin":[0,0,0,0],"name":"Column04899"},"id":"1403","type":"Column"},{"attributes":{"children":[{"id":"1403"},{"id":"1405"}],"margin":[0,0,0,0],"name":"Row04957"},"id":"1402","type":"Row"},{"attributes":{"margin":[5,5,5,5],"name":"DataFrame04954","text":"&lt;table class=&quot;dataframe panel-df&quot;&gt;\n  &lt;thead&gt;\n    &lt;tr style=&quot;text-align: right;&quot;&gt;\n      &lt;th&gt;&lt;/th&gt;\n      &lt;th&gt;LocationDesc&lt;/th&gt;\n      &lt;th&gt;Topic&lt;/th& ...
#     var render_items = [{"docid":"5087f479-ce1b-44d5-a797-950c30fefe3a","root_ids":["1400"],"roots":{"1400":"9767fa85-c7ac-4986-8ace-5a87b86bbd63"}}];
#     root.Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   if (root.Bokeh !== undefined && root.Bokeh.Panel !== undefined && ( root['Tabulator'] !== undefined)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (root.Bokeh !== undefined && root.Bokeh.Panel !== undefined && (root['Tabulator'] !== undefined)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
#           console.log("Bokeh: ERROR: Unable to run BokehJS code because BokehJS library is missing");
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
disease_bar_chart = disease_states_bar_pipeline.hvplot(kind='bar',
                                                       frame_width=800,
                                                       frame_height=175,
                                                       x='LocationDesc',
                                                       y='Data_Value',
                                                       by='Topic',
                                                       xlabel='',
                                                       ylabel='Incidence Rate Per 100,000',
                                                       title="Average Rates By State (2000-2018)")
disease_bar_chart = disease_bar_chart.opts(cmap='reds', shared_axes=False)
disease_bar_chart
# Out:
# <div id='1409'>
#   <div class="bk-root" id="aca29f8b-db95-41a8-a5e6-d27c14b66121" data-root-id="1409"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"9d259f11-f856-4e81-8cd5-cf4d6ccd186e":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"NotificationAreaBase1","overrides":[],"properties":[{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"}]},{"extends":null,"module":null,"name":"NotificationArea1","overrides":[],"properties":[{"default":[],"kind":null,"name":"notifications"},{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"},{"default":[{"background":"#ffc107","icon":{"className":"fas fa-exclamation-triangle","color":"white","tagName":"i"},"type":"warning"},{"background":"#007bff","icon":{"className":"fas fa-info-circle","color":"white","tagName":"i"},"type":"info"}],"kind":null,"name":"types"}]},{"extends":null,"module":null,"name":"Notification","overrides":[],"properties":[{"default":null,"kind":null,"name":"background"},{"default":3000,"kind":null,"name":"duration"},{"default":null,"kind":null,"name":"icon"},{"default":"","kind":null,"name":"message"},{"default":null,"kind":null,"name":"notification_type"},{"default":false,"kind":null,"name":"_destroyed"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{},"id":"1438","type":"ResetTool"},{"attributes":{},"id":"1470","type":"UnionRenderers"},{"attributes":{"children":[{"id":"1411"},{"id":"1418"}],"margin":[0,0,0,0],"name":"Column05357"},"id":"1410","type":"Column"},{"attributes":{"factors":["Acute Myocardial Infarction","Coronary Heart Disease","Diseases of the Heart","Heart Failure","Major Cardiovascular Disease","Stroke"],"palette":["#fff5f0","#fdcab5","#fc8a6a","#f14432","#bc141a","#67000d"]},"id":"1447","type":"CategoricalColorMapper"},{"attributes":{"data":{"Data_Value":{"__ndarray__":"2FBeQ3mNUEAWCCPtWHFiQKrfc0uc2nNAfG6JU7/nSkAQRtqxAuF5QCWDxj9N8kVA","dtype":"float64","order":"little","shape":[6]},"LocationDesc":["Alabama","Alabama","Alabama","Alabama","Alabama","Alabama"],"Topic":["Acute Myocardial Infarction","Coronary Heart Disease","Diseases of the Heart","Heart Failure","Major Cardiovascular Disease","Stroke"],"xoffsets":[["Alabama","Acute Myocardial Infarction"],["Alabama","Coronary Heart Disease"],["Alabama","Diseases of the Heart"],["Alabama","Heart Failure"],["Alabama","Major Cardiovascular Disease"],["Alabama","Stroke"]]},"selected":{"id":"1449"},"selection_policy":{"id":"1470"}},"id":"1448","type":"ColumnDataSource"},{"attributes":{},"id":"1423","type":"CategoricalScale"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"field":"Topic","transform":{"id":"1447"}},"hatch_alpha":{"value":0.1},"hatch_color":{"field":"Topic","transform": ...

# %% [markdown]
# #### Gender Bar Chart

# %%
gender = df[(df['Break_Out_Category'] == 'Gender')]
gender = list(gender['Break_Out'].unique())
gender
# Out:
# ['Female', 'Male']

# %%
gender_pipeline = (
    idf[
        (idf.Year == year_select) &
        (idf.LocationDesc == state_select) &
        (idf.Topic == disease_select) &
        (idf.Break_Out.isin(gender)) &
        (idf.Data_Value_TypeID == 'AgeStdz')
    ]
    .groupby(['Year','LocationDesc','Topic','Break_Out'])['Data_Value'].mean()
    .to_frame()
    .reset_index()
    .sort_values(by='LocationDesc')
    .reset_index(drop=True)
)

# %%
gender_pipeline
# Out:
# <div id='1554'>
#   <div class="bk-root" id="f3d995a2-17a8-4587-a940-9511eeaa0c70" data-root-id="1554"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"8bd7d4cc-fff2-4355-96a8-55417c6725b8":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"NotificationAreaBase1","overrides":[],"properties":[{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"}]},{"extends":null,"module":null,"name":"NotificationArea1","overrides":[],"properties":[{"default":[],"kind":null,"name":"notifications"},{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"},{"default":[{"background":"#ffc107","icon":{"className":"fas fa-exclamation-triangle","color":"white","tagName":"i"},"type":"warning"},{"background":"#007bff","icon":{"className":"fas fa-info-circle","color":"white","tagName":"i"},"type":"info"}],"kind":null,"name":"types"}]},{"extends":null,"module":null,"name":"Notification","overrides":[],"properties":[{"default":null,"kind":null,"name":"background"},{"default":3000,"kind":null,"name":"duration"},{"default":null,"kind":null,"name":"icon"},{"default":"","kind":null,"name":"message"},{"default":null,"kind":null,"name":"notification_type"},{"default":false,"kind":null,"name":"_destroyed"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"margin":[5,10,5,10],"options":["Alabama","Alaska","Arizona","Arkansas","California","Colorado","Connecticut","Delaware","Florida","Georgia","Hawaii","Idaho","Illinois","Indiana","Iowa","Kansas","Kentucky","Louisiana","Maine","Maryland","Massachusetts","Michigan","Minnesota","Mississippi","Missouri","Montana","Nebraska","Nevada","New Hampshire","New Jersey","New Mexico","New York","North Carolina","North Dakota","Ohio","Oklahoma","Oregon","Pennsylvania","Rhode Island","South Carolina","South Dakota","Tennessee","Texas","Utah","Vermont","Virginia","Washington","West Virginia","Wisconsin","Wyoming"],"title":"State","value":"Alabama"},"id":"1559","type":"panel.models.widgets.CustomSelect"},{"attributes":{"margin":[5,10,5,10],"options":["2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018"],"title":"Year","value":"2000"},"id":"1558","type":"panel.models.widgets.CustomSelect"},{"attributes":{"children":[{"id":"1563"}],"margin":[0,0,0,0],"name":"Row07406"},"id":"1562","type":"Row"},{"attributes":{"children":[{"id":"1556"},{"id":"1562"}],"margin":[0,0,0,0],"name":"Column07463"},"id":"1555","type":"Column"},{"attributes":{"margin":[5,10,5,10],"options":["Heart Failure","Major Cardiovascular Disease","Stroke","Diseases of the Heart","Coronary Heart Disease","Acute Myocardial Infarction"],"title":"Disease","value":"Heart Failure"},"id": ...
#     var render_items = [{"docid":"8bd7d4cc-fff2-4355-96a8-55417c6725b8","root_ids":["1554"],"roots":{"1554":"f3d995a2-17a8-4587-a940-9511eeaa0c70"}}];
#     root.Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   if (root.Bokeh !== undefined && root.Bokeh.Panel !== undefined && ( root['Tabulator'] !== undefined)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (root.Bokeh !== undefined && root.Bokeh.Panel !== undefined && (root['Tabulator'] !== undefined)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
#           console.log("Bokeh: ERROR: Unable to run BokehJS code because BokehJS library is missing");
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
gender_bar_chart = gender_pipeline.hvplot.barh(
                                          frame_width=300,
                                          frame_height=175,
                                          x='Break_Out',
                                          y='Data_Value',
                                          color='Data_Value',
                                          cmap=['maroon','lavenderblush'],
                                          alpha=0.85,
                                          xlabel='Gender',
                                          ylabel='Incidence Rate Per 100,000',
                                          title="Average Rates By Gender")
gender_bar_chart
# Out:
# <div id='1565'>
#   <div class="bk-root" id="5f07f457-9c96-4c66-bf89-a430b719e2ee" data-root-id="1565"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"f407a0ca-a7f1-4fb3-ab61-52a0248f95e9":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"NotificationAreaBase1","overrides":[],"properties":[{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"}]},{"extends":null,"module":null,"name":"NotificationArea1","overrides":[],"properties":[{"default":[],"kind":null,"name":"notifications"},{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"},{"default":[{"background":"#ffc107","icon":{"className":"fas fa-exclamation-triangle","color":"white","tagName":"i"},"type":"warning"},{"background":"#007bff","icon":{"className":"fas fa-info-circle","color":"white","tagName":"i"},"type":"info"}],"kind":null,"name":"types"}]},{"extends":null,"module":null,"name":"Notification","overrides":[],"properties":[{"default":null,"kind":null,"name":"background"},{"default":3000,"kind":null,"name":"duration"},{"default":null,"kind":null,"name":"icon"},{"default":"","kind":null,"name":"message"},{"default":null,"kind":null,"name":"notification_type"},{"default":false,"kind":null,"name":"_destroyed"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.85},"fill_color":{"field":"color","transform":{"id":"1605"}},"hatch_alpha":{"value":0.85},"hatch_color":{"field":"color","transform":{"id":"1605"}},"height":{"value":0.8},"line_alpha":{"value":0.85},"right":{"field":"Data_Value"},"y":{"field":"Break_Out"}},"id":"1612","type":"HBar"},{"attributes":{"axis_label":"Incidence Rate Per 100,000","coordinates":null,"formatter":{"id":"1617"},"group":null,"major_label_policy":{"id":"1618"},"ticker":{"id":"1586"}},"id":"1585","type":"LinearAxis"},{"attributes":{},"id":"1607","type":"Selection"},{"attributes":{},"id":"1581","type":"LinearScale"},{"attributes":{"source":{"id":"1606"}},"id":"1615","type":"CDSView"},{"attributes":{"axis":{"id":"1589"},"coordinates":null,"dimension":1,"grid_line_color":null,"group":null,"ticker":null},"id":"1591","type":"Grid"},{"attributes":{"client_comm_id":"490ea844561d413c9e65b1f25f29beed","comm_id":"61d753d15b02458b8e6bc56c37f122b1","plot_id":"1565"},"id":"1662","type":"panel.models.comm_manager.CommManager"},{"attributes":{},"id":"1583","type":"CategoricalScale"},{"attributes":{"factors":["Female","Male"],"tags":[[["Break_Out","Break_Out",null]]]},"id":"1574","type":"FactorRange"},{"attributes":{"data":{"Break_Out":["Female","Male"],"Data_Value":{"__ndarray__":"MzMzMzPzT0CamZmZmRlMQA==","dtype":"float64","order":"little","shape":[2]},"color":{"__ndarray__":"MzMzMzPzT0CamZmZmRlMQA==","dtype":"float64","order ...

# %% [markdown]
# #### Age Bar Chart

# %%
age_pipeline = (
    idf[
        (idf.Year == year_select) &
        (idf.LocationDesc == state_select) &
        (idf.Topic == disease_select) &
        (idf.Break_Out.isin(age))
    ]
    .groupby(['Year','LocationDesc','Topic','Break_Out'])['Data_Value'].mean()
    .to_frame()
    .reset_index()
    .sort_values(by=['Year','LocationDesc','Break_Out'])
    .reset_index(drop=True)
)

# %%
age_pipeline
# Out:
# <div id='1713'>
#   <div class="bk-root" id="6c32a5c6-49aa-44e2-8637-49036c6c1d1a" data-root-id="1713"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"ac5a429b-4ad6-445b-bdd6-364b33a40a27":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"NotificationAreaBase1","overrides":[],"properties":[{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"}]},{"extends":null,"module":null,"name":"NotificationArea1","overrides":[],"properties":[{"default":[],"kind":null,"name":"notifications"},{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"},{"default":[{"background":"#ffc107","icon":{"className":"fas fa-exclamation-triangle","color":"white","tagName":"i"},"type":"warning"},{"background":"#007bff","icon":{"className":"fas fa-info-circle","color":"white","tagName":"i"},"type":"info"}],"kind":null,"name":"types"}]},{"extends":null,"module":null,"name":"Notification","overrides":[],"properties":[{"default":null,"kind":null,"name":"background"},{"default":3000,"kind":null,"name":"duration"},{"default":null,"kind":null,"name":"icon"},{"default":"","kind":null,"name":"message"},{"default":null,"kind":null,"name":"notification_type"},{"default":false,"kind":null,"name":"_destroyed"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"children":[{"id":"1722"}],"margin":[0,0,0,0],"name":"Row09415"},"id":"1721","type":"Row"},{"attributes":{"margin":[5,10,5,10],"options":["Alabama","Alaska","Arizona","Arkansas","California","Colorado","Connecticut","Delaware","Florida","Georgia","Hawaii","Idaho","Illinois","Indiana","Iowa","Kansas","Kentucky","Louisiana","Maine","Maryland","Massachusetts","Michigan","Minnesota","Mississippi","Missouri","Montana","Nebraska","Nevada","New Hampshire","New Jersey","New Mexico","New York","North Carolina","North Dakota","Ohio","Oklahoma","Oregon","Pennsylvania","Rhode Island","South Carolina","South Dakota","Tennessee","Texas","Utah","Vermont","Virginia","Washington","West Virginia","Wisconsin","Wyoming"],"title":"State","value":"Alabama"},"id":"1718","type":"panel.models.widgets.CustomSelect"},{"attributes":{"client_comm_id":"17b56a85712c414f8aac90e781008efc","comm_id":"5d71cfcdd73b4a48b359928feba1c3ac","plot_id":"1713"},"id":"1723","type":"panel.models.comm_manager.CommManager"},{"attributes":{"children":[{"id":"1715"},{"id":"1721"}],"margin":[0,0,0,0],"name":"Column09469"},"id":"1714","type":"Column"},{"attributes":{"children":[{"id":"1714"}],"margin":[0,0,0,0],"name":"Row09470"},"id":"1713","type":"Row"},{"attributes":{"margin":[5,5,5,5],"name":"DataFrame09465","text":"&lt;table class=&quot;dataframe panel-df&quot;&gt;\n  &lt;thead&gt;\n    &lt;tr style=&quot;text-align: right;&quot;&gt;\n      &lt;th&gt ...
#     var render_items = [{"docid":"ac5a429b-4ad6-445b-bdd6-364b33a40a27","root_ids":["1713"],"roots":{"1713":"6c32a5c6-49aa-44e2-8637-49036c6c1d1a"}}];
#     root.Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   if (root.Bokeh !== undefined && root.Bokeh.Panel !== undefined && ( root['Tabulator'] !== undefined)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (root.Bokeh !== undefined && root.Bokeh.Panel !== undefined && (root['Tabulator'] !== undefined)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
#           console.log("Bokeh: ERROR: Unable to run BokehJS code because BokehJS library is missing");
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
age_bar_chart = age_pipeline.hvplot.barh(
                                          frame_width=300,
                                          frame_height=175,
                                          x='Break_Out',
                                          y='Data_Value',
                                          color='Data_Value',
                                          cmap='reds',
                                          alpha=0.75,
                                          xlabel='Age',
                                          ylabel='Incidence Rate Per 100,000',
                                          title="Average Rates By Age")
age_bar_chart
# Out:
# <div id='1724'>
#   <div class="bk-root" id="adbdd696-e019-4aea-a7af-dc4f4d157a2f" data-root-id="1724"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"ef91d65e-d649-4539-8593-3c1faf7df0bd":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"NotificationAreaBase1","overrides":[],"properties":[{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"}]},{"extends":null,"module":null,"name":"NotificationArea1","overrides":[],"properties":[{"default":[],"kind":null,"name":"notifications"},{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"},{"default":[{"background":"#ffc107","icon":{"className":"fas fa-exclamation-triangle","color":"white","tagName":"i"},"type":"warning"},{"background":"#007bff","icon":{"className":"fas fa-info-circle","color":"white","tagName":"i"},"type":"info"}],"kind":null,"name":"types"}]},{"extends":null,"module":null,"name":"Notification","overrides":[],"properties":[{"default":null,"kind":null,"name":"background"},{"default":3000,"kind":null,"name":"duration"},{"default":null,"kind":null,"name":"icon"},{"default":"","kind":null,"name":"message"},{"default":null,"kind":null,"name":"notification_type"},{"default":false,"kind":null,"name":"_destroyed"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"data":{"Break_Out":["25-44","35+","45-64","65+","75+"],"Data_Value":{"__ndarray__":"AAAAAAAAAEAAAAAAAOBWQDMzMzMzMzBAMzMzMzODdEAAAAAAANiCQA==","dtype":"float64","order":"little","shape":[5]},"color":{"__ndarray__":"AAAAAAAAAEAAAAAAAOBWQDMzMzMzMzBAMzMzMzODdEAAAAAAANiCQA==","dtype":"float64","order":"little","shape":[5]}},"selected":{"id":"1766"},"selection_policy":{"id":"1788"}},"id":"1765","type":"ColumnDataSource"},{"attributes":{},"id":"1745","type":"BasicTicker"},{"attributes":{"margin":[5,5,5,5],"name":"HSpacer09665","sizing_mode":"stretch_width"},"id":"1731","type":"Spacer"},{"attributes":{"tools":[{"id":"1734"},{"id":"1751"},{"id":"1752"},{"id":"1753"},{"id":"1754"},{"id":"1755"}]},"id":"1757","type":"Toolbar"},{"attributes":{"axis_label":"Age","coordinates":null,"formatter":{"id":"1779"},"group":null,"major_label_policy":{"id":"1780"},"ticker":{"id":"1749"}},"id":"1748","type":"CategoricalAxis"},{"attributes":{"source":{"id":"1765"}},"id":"1774","type":"CDSView"},{"attributes":{"callback":null,"renderers":[{"id":"1773"}],"tags":["hv_created"],"tooltips":[["Break_Out","@{Break_Out}"],["Data_Value","@{Data_Value}"]]},"id":"1734","type":"HoverTool"},{"attributes":{},"id":"1753","type":"WheelZoomTool"},{"attributes":{},"id":"1752","type":"PanTool"},{"attributes":{"below":[{"id":"1744"}],"center":[{"id":"1747"},{"id":"1750"}],"frame_height":175,"frame_width":300,"height":null,"left":[{"id":"1748"}],"ma ...

# %% [markdown]
# #### Race Bar Chart

# %%
race = ['Other', 'Black', 'Hispanic', 'White']

race_pipeline = (
    idf[
        (idf.Year == year_select) & 
        (idf.LocationDesc == state_select) & 
        (idf.Topic == disease_select) &
        (idf.Break_Out.isin(race)) &
        (idf.Data_Value_TypeID == 'AgeStdz')
    ]
    .groupby(['Year','LocationDesc','Topic','Break_Out'])['Data_Value'].mean()
    .to_frame()
    .reset_index()
    .sort_values(by=['Year','LocationDesc','Break_Out'])
    .reset_index(drop=True)
)

# %%
race_pipeline
# Out:
# <div id='1872'>
#   <div class="bk-root" id="f3a20367-e4ef-4356-9ebb-762cdebecbb6" data-root-id="1872"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"e912bfda-1156-4cba-a7b7-805d24b6788e":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"NotificationAreaBase1","overrides":[],"properties":[{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"}]},{"extends":null,"module":null,"name":"NotificationArea1","overrides":[],"properties":[{"default":[],"kind":null,"name":"notifications"},{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"},{"default":[{"background":"#ffc107","icon":{"className":"fas fa-exclamation-triangle","color":"white","tagName":"i"},"type":"warning"},{"background":"#007bff","icon":{"className":"fas fa-info-circle","color":"white","tagName":"i"},"type":"info"}],"kind":null,"name":"types"}]},{"extends":null,"module":null,"name":"Notification","overrides":[],"properties":[{"default":null,"kind":null,"name":"background"},{"default":3000,"kind":null,"name":"duration"},{"default":null,"kind":null,"name":"icon"},{"default":"","kind":null,"name":"message"},{"default":null,"kind":null,"name":"notification_type"},{"default":false,"kind":null,"name":"_destroyed"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"children":[{"id":"1875"},{"id":"1879"}],"margin":[0,0,0,0],"name":"Row11686"},"id":"1874","type":"Row"},{"attributes":{"children":[{"id":"1881"}],"margin":[0,0,0,0],"name":"Row11630"},"id":"1880","type":"Row"},{"attributes":{"margin":[5,5,5,5],"name":"HSpacer11685","sizing_mode":"stretch_width"},"id":"1879","type":"Spacer"},{"attributes":{"children":[{"id":"1876"},{"id":"1877"},{"id":"1878"}],"margin":[0,0,0,0],"name":"Column11625"},"id":"1875","type":"Column"},{"attributes":{"children":[{"id":"1874"},{"id":"1880"}],"margin":[0,0,0,0],"name":"Column11687"},"id":"1873","type":"Column"},{"attributes":{"margin":[5,10,5,10],"options":["2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018"],"title":"Year","value":"2000"},"id":"1876","type":"panel.models.widgets.CustomSelect"},{"attributes":{"client_comm_id":"089032f53a834c73b35f2b218ab28f94","comm_id":"e8882f15815147619fc38277a414a54f","plot_id":"1872"},"id":"1882","type":"panel.models.comm_manager.CommManager"},{"attributes":{"children":[{"id":"1873"}],"margin":[0,0,0,0],"name":"Row11688"},"id":"1872","type":"Row"},{"attributes":{"margin":[5,5,5,5],"name":"DataFrame11683","text":"&lt;table class=&quot;dataframe panel-df&quot;&gt;\n  &lt;thead&gt;\n    &lt;tr style=&quot;text-align: right;&quot;&gt;\n      &lt;th&gt;&lt;/th&gt;\n      &lt;th&gt;Year&lt;/th&gt;\n      &lt;th&gt;Loca ...
#     var render_items = [{"docid":"e912bfda-1156-4cba-a7b7-805d24b6788e","root_ids":["1872"],"roots":{"1872":"f3a20367-e4ef-4356-9ebb-762cdebecbb6"}}];
#     root.Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   if (root.Bokeh !== undefined && root.Bokeh.Panel !== undefined && ( root['Tabulator'] !== undefined)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (root.Bokeh !== undefined && root.Bokeh.Panel !== undefined && (root['Tabulator'] !== undefined)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
#           console.log("Bokeh: ERROR: Unable to run BokehJS code because BokehJS library is missing");
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
race_bar_chart = race_pipeline.hvplot.barh(
                                      frame_width=300,
                                      frame_height=175,
                                      x='Break_Out',
                                      y='Data_Value',
                                      color='Data_Value',
                                      cmap='reds',
                                      xlabel='Race',
                                      ylabel='Incidence Rate Per 100,000',
                                      title="Average Rates By Race")
race_bar_chart
# Out:
# <div id='1883'>
#   <div class="bk-root" id="9c025402-c1a9-47ad-800f-3c98482b3d05" data-root-id="1883"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"d4e515ff-26ac-42ab-acd7-b18cdf88d6ac":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"NotificationAreaBase1","overrides":[],"properties":[{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"}]},{"extends":null,"module":null,"name":"NotificationArea1","overrides":[],"properties":[{"default":[],"kind":null,"name":"notifications"},{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"},{"default":[{"background":"#ffc107","icon":{"className":"fas fa-exclamation-triangle","color":"white","tagName":"i"},"type":"warning"},{"background":"#007bff","icon":{"className":"fas fa-info-circle","color":"white","tagName":"i"},"type":"info"}],"kind":null,"name":"types"}]},{"extends":null,"module":null,"name":"Notification","overrides":[],"properties":[{"default":null,"kind":null,"name":"background"},{"default":3000,"kind":null,"name":"duration"},{"default":null,"kind":null,"name":"icon"},{"default":"","kind":null,"name":"message"},{"default":null,"kind":null,"name":"notification_type"},{"default":false,"kind":null,"name":"_destroyed"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{},"id":"1904","type":"BasicTicker"},{"attributes":{"end":62.75,"reset_end":62.75,"reset_start":0.0,"tags":[[["Data_Value","Data_Value",null]]]},"id":"1891","type":"Range1d"},{"attributes":{"axis_label":"Race","coordinates":null,"formatter":{"id":"1938"},"group":null,"major_label_policy":{"id":"1939"},"ticker":{"id":"1908"}},"id":"1907","type":"CategoricalAxis"},{"attributes":{"children":[{"id":"1886"},{"id":"1890"}],"margin":[0,0,0,0],"name":"Row11887"},"id":"1885","type":"Row"},{"attributes":{},"id":"1912","type":"WheelZoomTool"},{"attributes":{"callback":null,"renderers":[{"id":"1932"}],"tags":["hv_created"],"tooltips":[["Break_Out","@{Break_Out}"],["Data_Value","@{Data_Value}"]]},"id":"1893","type":"HoverTool"},{"attributes":{},"id":"1947","type":"UnionRenderers"},{"attributes":{},"id":"1911","type":"PanTool"},{"attributes":{"margin":[5,10,5,10],"options":["Alabama","Alaska","Arizona","Arkansas","California","Colorado","Connecticut","Delaware","Florida","Georgia","Hawaii","Idaho","Illinois","Indiana","Iowa","Kansas","Kentucky","Louisiana","Maine","Maryland","Massachusetts","Michigan","Minnesota","Mississippi","Missouri","Montana","Nebraska","Nevada","New Hampshire","New Jersey","New Mexico","New York","North Carolina","North Dakota","Ohio","Oklahoma","Oregon","Pennsylvania","Rhode Island","South Carolina","South Dakota","Tennessee","Texas","Utah","Vermont","Virginia","Washington","West Virginia","Wisc ...

# %% [markdown]
# #### Dashboard Creation

# %%
link = link_selections.instance()

linked = link(gender_bar_chart + age_bar_chart + race_bar_chart).opts(shared_axes=False)
linked
# Out:
# <div id='2031'>
#   <div class="bk-root" id="362f4a21-2e6f-4f2b-a941-8b0cfa6a9def" data-root-id="2031"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"f447b507-4e89-4c06-a8f3-166f55a2cd5e":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"NotificationAreaBase1","overrides":[],"properties":[{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"}]},{"extends":null,"module":null,"name":"NotificationArea1","overrides":[],"properties":[{"default":[],"kind":null,"name":"notifications"},{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"},{"default":[{"background":"#ffc107","icon":{"className":"fas fa-exclamation-triangle","color":"white","tagName":"i"},"type":"warning"},{"background":"#007bff","icon":{"className":"fas fa-info-circle","color":"white","tagName":"i"},"type":"info"}],"kind":null,"name":"types"}]},{"extends":null,"module":null,"name":"Notification","overrides":[],"properties":[{"default":null,"kind":null,"name":"background"},{"default":3000,"kind":null,"name":"duration"},{"default":null,"kind":null,"name":"icon"},{"default":"","kind":null,"name":"message"},{"default":null,"kind":null,"name":"notification_type"},{"default":false,"kind":null,"name":"_destroyed"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{},"id":"2122","type":"Selection"},{"attributes":{"factors":["25-44","35+","45-64","65+","75+"],"tags":[[["Break_Out","Break_Out",null]]]},"id":"2089","type":"FactorRange"},{"attributes":{},"id":"2047","type":"LinearScale"},{"attributes":{"bottom_units":"screen","coordinates":null,"fill_alpha":0.5,"fill_color":"lightgrey","group":null,"left_units":"screen","level":"overlay","line_alpha":1.0,"line_color":"black","line_dash":[4,4],"line_width":2,"right_units":"screen","syncable":false,"top_units":"screen"},"id":"2161","type":"BoxAnnotation"},{"attributes":{"margin":[5,10,5,10],"options":["2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018"],"title":"Year","value":"2000"},"id":"2035","type":"panel.models.widgets.CustomSelect"},{"attributes":{},"id":"2084","type":"AllLabels"},{"attributes":{"axis_label":"Incidence Rate Per 100,000","coordinates":null,"formatter":{"id":"2083"},"group":null,"major_label_policy":{"id":"2084"},"ticker":{"id":"2052"}},"id":"2051","type":"LinearAxis"},{"attributes":{},"id":"2083","type":"BasicTickFormatter"},{"attributes":{},"id":"2133","type":"AllLabels"},{"attributes":{"end":64.67,"reset_end":64.67,"reset_start":0.0,"tags":[[["Data_Value","Data_Value",null]]]},"id":"2039","type":"Range1d"},{"attributes":{"factors":["Female","Male"],"tags":[[["Break_Out","Break_Out",null]]]},"id":"2040","type":"FactorR ...

# %%
widgets = pn.WidgetBox(year_select, state_select, disease_select, margin=5)

template = pn.template.FastListTemplate(
    title='Cardiovascular Disease in USA',
    sidebar=[pn.pane.Markdown('## Visualization of incidence rates of cardiovascular diseases that occurred in the United States from 2000-2018. Data retrieved from National Vital Statistics System.'),
             pn.pane.Markdown('## Settings'),
             widgets,
             pn.pane.Markdown('###### Dashboard created by Thanh-Trang Tran')],
    main=[pn.Row(pn.Column(disease_state_timeline.panel(width=1000))),
          pn.Row(pn.Column(disease_bar_chart.panel(width=1000))),
          pn.Row(pn.Column(linked.panel(width=370)))],
    header_background='#8B0A50',
)

#template.show()
template.servable();
# Out:
# Launching server at http://localhost:50470
